# %%
def pre_processing():
    
    # go throught the corpus for etract the vocabu and split raw file into sentences
    labels = {}
    tokens = {} 
    token_count = {} 
    label_count = {} 
    character_count = {}
    path = '../data/conll_test_files/'
    datasets = [('train',path+'train.txt'), ('eval', path+'eval.txt'), ('test', path+'test.txt')]
    for dataset in datasets:
        labels[dataset[0]], tokens[dataset[0]], token_count[dataset[0]], \
        label_count[dataset[0]], character_count[dataset[0]] = CoNLL_Parser(dataset[1])
    
    vocab_token_corpus = count_token['train'] + count_token['eval'] + count_token['test']
    vocab_label = count_label['train'] + count_label['eval'] + count_label['test']
    vocab_char = count_character['train'] + count_character['eval'] + count_character['test']
    
    
    # future feature, limit the vocab size to the most frequent token
#     if config.vocabu_threashold > 0
#         pass

# %%
# go throught the corpus for etract the vocabu and split raw file into sentences
labels = {}
tokens = {} 
count_token = {} 
count_label = {} 
count_character = {}
path = '../data/conll_test_files/'
datasets = [('train',path+'train.txt'), ('eval', path+'eval.txt'), ('test', path+'test.txt')]
for dataset in datasets:
    labels[dataset[0]], tokens[dataset[0]], count_token[dataset[0]], \
    count_label[dataset[0]], count_character[dataset[0]] = CoNLL_Parser(dataset[1])

vocab_token_corpus = count_token['train'] + count_token['eval'] + count_token['test']
vocab_label = count_label['train'] + count_label['eval'] + count_label['test']
vocab_char = count_character['train'] + count_character['eval'] + count_character['test']

# %%
set(vocab_token_corpus.keys())
# Out:
# {'$NUM$',
#  '.',
#  '123test123',
#  'a',
#  'actor',
#  'american',
#  'an',
#  'and',
#  'economic',
#  'european',
#  'french',
#  'in',
#  'is',
#  'jean',
#  'lives',
#  'new',
#  'oscar',
#  'pierre',
#  'political',
#  'test123',
#  'the',
#  'union',
#  'won',
#  'york'}

# %%
len(vocab_glove & set(vocab_token_corpus.keys()))
# Out:
# 21

# %%
def get_glove_vocab(filename):
    print("Building vocab...")
    vocab = set()
    with open(filename) as f:
        for line in f:
            word = line.strip().split(' ')[0]
            vocab.add(word)
    print("- done. {} tokens".format(len(vocab)))
    return vocab

# %%
! ls ../data/glove
# Out:
# glove.6B.100d.txt

# %%
filename_glove = '../data/glove/glove.6B.100d.txt'
vocab_glove = get_glove_vocab(filename_glove)
# Out:
# Building vocab...
# - done. 400000 tokens

# %%
type(vocab_glove)
# Out:
# set

# %% [markdown]
# # 1.CoNLL_Parser

# %%
path_test_conll_file1 = '../data/conll_test_files/Alliance114418822/Alliance114418822_fold1.conll'
path_test_conll_file2 = '../data/conll_test_files/stanford_ner_without_start_without_empty_space.tsv'

# %%
! ls ../data/conll_test_files/
# Out:
# Alliance114418822
# stanford_ner_without_start_without_empty_space.tsv

# %%
# first 10 lines in test file
! head -40 ../data/conll_test_files/Alliance114418822/Alliance114418822_fold1.conll
# Out:
# 1234	O
# 5678	O
# 345TEST	O
# 66TEST	O
# TEST	O
#
# At    O
# the    O
# same    O
# time    O
# ,    O
# however    O
# ,    O
# the    O
# party    O
# did    O
# not    O
# join    O
# its    O
# Warsaw    B-Alliance114418822
# Pact    I-Alliance114418822
# brethren    O
# in    O
# de    O
# -    O
# Stalinization    O
# .    O
#
# On    O
# the    O
# outside    O
# too    O
# ,    O
# the    O
# PMR    O
# ,    O
# leading    O
# a    O
# country    O

# %%
import sklearn.preprocessing
# import utils
import collections
import codecs
# import utils_nlp
import re
import time
import token
import os
import pickle
import random

# %%
def CoNLL_Parser(filepath, sparator = ' ', lowercase = True):
    """
    Need CoNLL file using -DOCSTART- or empty line for sentence sparator
    """
    UNK = "$UNK$"
    NUM = "$NUM$"
    NONE = "O"
    
    count_token = collections.Counter()
    count_label = collections.Counter()
    count_character = collections.Counter()

    tokens = []
    labels = []
    sentence_tokens = []
    sentence_labels = []
    if filepath:
        f = codecs.open(filepath, 'r', 'UTF-8')
#         with open(filepath, 'r') as f:


        for line in f:
            line = line.strip().replace(sparator, '\t').split('\t')

            # Save previous sentence at the end of it and start to the next sentence
            if len(line) == 0 or len(line[0]) == 0 or '-DOCSTART-' in line[0]:
                if len(sentence_tokens) > 0:
                    labels.append(sentence_labels)
                    tokens.append(sentence_tokens)
                    sentence_tokens = []
                    sentence_labels = []
                continue
            
            
            token = str(line[0])
            for character in token:
                count_character.update({character: 1})


            # lowercase & digit
            if lowercase:
                token = str(line[0]).lower()
            else:
                token = str(line[0])
            if token.isdigit():
                token = NUM
                
            label = str(line[-1])
            count_token.update({token: 1})
            count_label.update({label: 1})               
            sentence_tokens.append(token)
            sentence_labels.append(label)

        if len(sentence_tokens) > 0:
            labels.append(sentence_labels)
            tokens.append(sentence_tokens)
        
        f.close()    
            
    return labels, tokens, count_token, count_label, count_character

# %%
labels, tokens, token_count, label_count, character_count = CoNLL_Parser(path_test_conll_file1)

# %%
labels[:2]
# Out:
# [['O', 'O', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Alliance114418822',
#   'I-Alliance114418822',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O']]

# %%
tokens[:2]
# Out:
# [['$NUM$', '$NUM$', '345test', '66test', 'test'],
#  ['at',
#   'the',
#   'same',
#   'time',
#   ',',
#   'however',
#   ',',
#   'the',
#   'party',
#   'did',
#   'not',
#   'join',
#   'its',
#   'warsaw',
#   'pact',
#   'brethren',
#   'in',
#   'de',
#   '-',
#   'stalinization',
#   '.']]

# %%
print('size of chars vocabu :',len(character_count.keys()))
character_count.most_common(100)[-20:]
# Out:
# size of chars vocabu : 127
# [('’', 5),
#  ('&', 5),
#  ('è', 4),
#  ('ō', 4),
#  ('…', 4),
#  ('ö', 4),
#  ('ū', 4),
#  ('ș', 3),
#  ('ć', 3),
#  ('ı', 3),
#  ('Ş', 3),
#  ('в', 2),
#  ('í', 2),
#  ('ç', 2),
#  ('[', 2),
#  (']', 2),
#  ('ë', 2),
#  ('ó', 2),
#  ('ł', 2),
#  ('ā', 2)]

# %%
label_count
# Out:
# Counter({'B-Alliance114418822': 984, 'I-Alliance114418822': 724, 'O': 27947})

# %%
test = {}
test = label_count + token_count
test
# Out:
# Counter({'O': 27947,
#          'B-Alliance114418822': 984,
#          'I-Alliance114418822': 724,
#          '$NUM$': 606,
#          '345test': 1,
#          '66test': 1,
#          'test': 1,
#          'at': 99,
#          'the': 2760,
#          'same': 11,
#          'time': 19,
#          ',': 1460,
#          'however': 19,
#          'party': 5,
#          'did': 12,
#          'not': 33,
#          'join': 13,
#          'its': 61,
#          'warsaw': 39,
#          'pact': 71,
#          'brethren': 1,
#          'in': 751,
#          'de': 11,
#          '-': 247,
#          'stalinization': 1,
#          '.': 863,
#          'on': 243,
#          'outside': 2,
#          'too': 4,
#          'pmr': 1,
#          'leading': 5,
#          'a': 369,
#          'country': 14,
#          'that': 129,
#          'had': 86,
#          'joined': 20,
#          'remained': 13,
#          'an': 97,
#          'agent': 2,
#          'of': 1121,
#          'political': 10,
# ...

# %% [markdown]
# ### Problem the size of bigger than excepted.

# %% [markdown]
# # 2.Token2idx + Deal with UNK

# %%
token_to_index = {}
token_to_index[self.UNK] = self.UNK_TOKEN_INDEX
iteration_number = 0
number_of_unknown_tokens = 0

for token, count in token_count['all'].items():
    if iteration_number == self.UNK_TOKEN_INDEX: iteration_number += 1

    if parameters['remap_unknown_tokens_to_unk'] == 1 and \
        (token_count['train'][token] == 0 or \
        parameters['load_only_pretrained_token_embeddings']) and \
        not utils_nlp.is_token_in_pretrained_embeddings(token, token_to_vector, parameters) and \
        token not in all_tokens_in_pretraining_dataset:
        token_to_index[token] =  self.UNK_TOKEN_INDEX
        number_of_unknown_tokens += 1
        self.tokens_mapped_to_unk.append(token)
    else:
        token_to_index[token] = iteration_number
        iteration_number += 1

# %% [markdown]
# * token_to_vector = utils_nlp.load_pretrained_token_embeddings(parameters) // do not modify like add new vectors
#
# * token_count['all'] : {word, count} : for all in train, test, valid, dev
# * add to token_count['all'] the vocabu in token_to_vector {-1}
# * same for chars
# * same for chars
# * order by frequency
# * set: token_to_index {word, integer} :
#     if not in train & not in token_to_vector & not in pretrained dataset --> UNK
#     == index ++
# * infrequent_token_indices
#
#
# * Label
#     * aligin ['B-', 'I-', 'E-', 'S-']
#     * order
#     * label_to_index
#
# * character
#     * character_to_index
#
# *idx2
#     index_to_token
#     label_to_index
#     index_to_character
#
#
# * _convert_to_indices
#     * 2idx
#     * max_length
#     * padding

# %%
# Generators object
dev   = CoNLLDataset(config.filename_dev, processing_word)
    lowercase 
    digit
